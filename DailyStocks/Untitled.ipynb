# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('DailyStock.csv')

# %%
df
# Out:
#      Symbol                                               Name LastSale  \
# 0    Symbol                            22nd Century Group, Inc     0.97
# 1       FAX              Aberdeen Asia-Pacific Income Fund Inc     4.88
# 2       IAF                 Aberdeen Australia Equity Fund Inc     6.02
# 3        CH                          Aberdeen Chile Fund, Inc.     6.61
# 4       ABE  Aberdeen Emerging Markets Smaller Company Oppo...    12.46
# 5       FCO                  Aberdeen Global Income Fund, Inc.     8.32
# 6        IF                      Aberdeen Indonesia Fund, Inc.     6.87
# 7       ISL                         Aberdeen Israel Fund, Inc.    17.25
# 8       ACU                           Acme United Corporation.    25.75
# 9      AIII                        ACRE Realty Investors, Inc.     1.22
# 10     ATNM                     Actinium Pharmaceuticals, Inc.     1.38
# 11       AE                     Adams Resources & Energy, Inc.    34.49
# ...

# %%
df['Sector'].unique()
# Out:
# array(['Consumer Non-Durables', 'n/a', 'Capital Goods',
#        'Consumer Services', 'Health Care', 'Energy', 'Technology',
#        'Basic Industries', 'Finance', 'Public Utilities', 'Miscellaneous',
#        'Consumer Durables', 'Transportation'], dtype=object)

# %%
df['Sector'].nunique()
# Out:
# 13

# %%
df['Industry'].unique()
# Out:
# array(['Farming/Seeds/Milling', 'n/a', 'Industrial Machinery/Components',
#        'Real Estate Investment Trusts', 'Major Pharmaceuticals',
#        'Oil Refining/Marketing', 'Hospital/Nursing Management',
#        'Diversified Commercial Services', 'Military/Government/Technical',
#        'Precious Metals', 'Industrial Specialties', 'Real Estate',
#        'Food Distributors', 'Power Generation', 'Packaged Foods',
#        'Medical Specialities',
#        'Biotechnology: Biological Products (No Diagnostic Substances)',
#        'Biotechnology: Electromedical & Electrotherapeutic Apparatus',
#        'Mining & Quarrying of Nonmetallic Minerals (No Fuels)',
#        'Professional Services', 'Business Services',
#        'Environmental Services', 'Major Banks', 'Oil & Gas Production',
#        'Consumer Specialties',
#        'Radio And Television Broadcasting And Communications Equipment',
#        'Medical/Dental Instruments', 'Oilfield Services/Equipment',
# ...

# %%
df['Industry'].nunique()
# Out:
# 69

# %%
da['Industry']
# Out:
# 0                                  Farming/Seeds/Milling
# 1                                                    n/a
# 2                                                    n/a
# 3                                                    n/a
# 4                                                    n/a
# 5                                                    n/a
# 6                                                    n/a
# 7                                                    n/a
# 8                        Industrial Machinery/Components
# 9                          Real Estate Investment Trusts
# 10                                 Major Pharmaceuticals
# 11                                Oil Refining/Marketing
# 12                           Hospital/Nursing Management
# 13                                                   n/a
# 14                       Diversified Commercial Services
# 15                         Military/Government/Technical
# ...

# %%
ds = df[df['Industry'] != 'n/a']

# %%
ds
# Out:
#      Symbol                                  Name LastSale     MarketCap  \
# 0    Symbol               22nd Century Group, Inc     0.97  8.797717e+07
# 8       ACU              Acme United Corporation.    25.75  8.561759e+07
# 9      AIII           ACRE Realty Investors, Inc.     1.22  2.499837e+07
# 10     ATNM        Actinium Pharmaceuticals, Inc.     1.38  7.693101e+07
# 11       AE        Adams Resources & Energy, Inc.    34.49  1.450000e+08
# 12      ADK             Adcare Health Systems Inc      1.2  2.392564e+07
# 14      ACY                     AeroCentury Corp.   9.9752  1.562814e+07
# 15     AIRI                  Air Industries Group     3.52  2.669274e+07
# 16      AXU                  Alexco Resource Corp      1.6  1.490000e+08
# 17      AAU                Almaden Minerals, Ltd.     1.04  9.365547e+07
# 18      APT                  Alpha Pro Tech, Ltd.      2.9  4.469351e+07
# 19     AAMC      Altisource Asset Management Corp     73.5  1.120000e+08
# ...

# %%
'ACU' not in ds['Symbol']
# Out:
# True

# %%
ds[ds['Symbol'] =='ACU']['Industry']
# Out:
# 8    Industrial Machinery/Components
# Name: Industry, dtype: object

# %%
ds.loc[8,'Industry']
# Out:
# 'Industrial Machinery/Components'
